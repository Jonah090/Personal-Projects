# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
fraud = pd.read_csv("C:/Users/H P/Desktop/ANACONDA/DESCISION TREE/ASSIGNMENT/Fraud_check.csv")
fraud
# Out:
#     Undergrad Marital.Status  City.Population  Work.Experience Urban  \
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
#      TaxIncome
# 0        68833
# 1        33700
# 2        36925
# 3        50190
# 4        81002
# ..         ...
# 595      76340
# ...

# %%
bins = [0,30000,100000]
group_names = ['Risky','Good']

# %%
fraud['Taxable_Income'] = pd.cut(np.array(fraud.TaxIncome),bins,labels=group_names)
fraud
# Out:
#     Undergrad Marital.Status  City.Population  Work.Experience Urban  \
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
#      TaxIncome Taxable_Income
# 0        68833           Good
# 1        33700           Good
# 2        36925           Good
# ...

# %%
fraud.head(50)
# Out:
#    Undergrad Marital.Status  City.Population  Work.Experience Urban  \
# 0         NO         Single            50047               10   YES
# 1        YES       Divorced           134075               18   YES
# 2         NO        Married           160205               30   YES
# 3        YES         Single           193264               15   YES
# 4         NO        Married            27533               28    NO
# 5         NO       Divorced           116382                0    NO
# 6         NO       Divorced            80890                8   YES
# 7        YES         Single           131253                3   YES
# 8         NO         Single           102481               12   YES
# 9        YES       Divorced           155482                4   YES
# 10        NO         Single           102602               19   YES
# 11        NO         Single            94875                6   YES
# 12        NO       Divorced           148033               14   YES
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
fraud['Urban']= label_encoder.fit_transform(fraud['Urban']) 
fraud['Undergrad']=label_encoder.fit_transform(fraud['Undergrad'])
fraud['Marital.Status']=label_encoder.fit_transform(fraud['Marital.Status'])

# %%
fraud
# Out:
#      Undergrad  Marital.Status  City.Population  Work.Experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      TaxIncome Taxable_Income
# 0        68833           Good
# 1        33700           Good
# ...

# %%
x=fraud.iloc[:,0:5]

# %%
x 
pd.set_option("display.max_rows", None) 
x
# Out:
#      Undergrad  Marital.Status  City.Population  Work.Experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# 5            0               0           116382                0      0
# 6            0               0            80890                8      1
# 7            1               2           131253                3      1
# 8            0               2           102481               12      1
# 9            1               0           155482                4      1
# 10           0               2           102602               19      1
# 11           0               2            94875                6      1
# ...

# %%
y=fraud.iloc[:,6]
y
# Out:
# 0       Good
# 1       Good
# 2       Good
# 3       Good
# 4       Good
# 5       Good
# 6       Good
# 7       Good
# 8       Good
# 9       Good
# 10     Risky
# 11      Good
# 12     Risky
# 13      Good
# 14      Good
# 15      Good
# 16     Risky
# 17      Good
# 18      Good
# 19     Risky
# 20      Good
# 21     Risky
# 22      Good
# 23      Good
# 24      Good
# 25      Good
# 26      Good
# 27      Good
# 28     Risky
# 29      Good
# 30      Good
# 31      Good
# 32      Good
# 33      Good
# 34     Risky
# 35      Good
# 36     Risky
# 37      Good
# 38     Risky
# 39      Good
# 40      Good
# 41      Good
# 42      Good
# 43      Good
# 44      Good
# 45      Good
# 46      Good
# 47      Good
# 48     Risky
# 49      Good
# 50      Good
# 51      Good
# 52      Good
# 53     Risky
# 54      Good
# 55     Risky
# 56      Good
# 57      Good
# 58     Risky
# 59      Good
# 60      Good
# 61     Risky
# 62      Good
# 63      Good
# 64      Good
# 65      Good
# ...

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=40)

# %%
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
tree.plot_tree(model);

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model)(model, 
                   feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],  
                   class_names=fraud.Taxable_Income,
                   filled=True)
fig.savefig("decistion_tree.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c8f29825d1b8> in <module>
#       1 fig = plt.figure(figsize=(25,20))
# ----> 2 _ = tree.plot_tree(model)(model,
#       3                    feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],
#       4                    class_names=fraud.Taxable_Income,
#       5                    filled=True)
#
# TypeError: 'list' object is not callable

# %%
x_train1, x_test1,y_train1,y_test1 = train_test_split(x,y, test_size=0.3,random_state=40)

# %%
model1 = DecisionTreeClassifier(criterion = 'entropy',max_depth=4)
model1.fit(x_train1,y_train1)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
tree.plot_tree(model1);

# %%
fig = plt.figure(figsize=(30,25))
_ = tree.plot_tree(model1)(model1, 
                   feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],  
                   class_names=fraud.Taxable_Income,
                   filled=True)
fig.savefig("decistion_tree.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-404b2384ec0a> in <module>
#       1 fig = plt.figure(figsize=(30,25))
# ----> 2 _ = tree.plot_tree(model1)(model1,
#       3                    feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],
#       4                    class_names=fraud.Taxable_Income,
#       5                    filled=True)
#
# TypeError: 'list' object is not callable

# %%
x_train2, x_test2,y_train2,y_test2 = train_test_split(x,y, test_size=0.4,random_state=40)

# %%
model2 = DecisionTreeClassifier(criterion = 'entropy',max_depth=5)
model2.fit(x_train2,y_train2)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
tree.plot_tree(model2);

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model2)(model2, 
                   feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],  
                   class_names=fraud.Taxable_Income,
                   filled=True)
fig.savefig("decistion_tree.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ccad7d084bb8> in <module>
#       1 fig = plt.figure(figsize=(25,20))
# ----> 2 _ = tree.plot_tree(model2)(model2,
#       3                    feature_names=['Undergrad','Marital.Status','City.Population','Work.Experience','Urban'],
#       4                    class_names=fraud.Taxable_Income,
#       5                    filled=True)
#
# TypeError: 'list' object is not callable

# %%
#In all the models the aim is to find the root node for the data from which its split, the data may be split into testing 
#and training datasets and to find the entropy , the entropy should be close to 0. The depth of the tree can be specified 
#from which the model is created upto that value.
